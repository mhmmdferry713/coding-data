# %%
from google.colab import drive
drive.mount ('/content/drive')

# logistic regression for feature importance
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot
import numpy as np
import pandas as pd
import pickle

filepath1 = '/content/drive/My Drive/low_rate_attack/coding+data/dataset/traindataset.csv'
filepath2 = '/content/drive/My Drive/low_rate_attack/coding+data/dataset/testdataset.csv'

train = pd.read_csv(filepath1)
test = pd.read_csv(filepath2)

train = train[train.notnull()]
test = test[test.notnull()]

train.head()
test.head()

feat_labels = list(train.columns)
print(feat_labels)

print(len(train))
print(len(test))

from sklearn import preprocessing
le = preprocessing.LabelEncoder()

X_train = train.drop(columns=['label'])
y_train = train['label'].values
# print(y_train)

X_train = X_train.apply(le.fit_transform)
y_train = le.fit_transform(y_train)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_important_train = scaler.fit_transform(X_train)

print("Logistic Regression")
model = LogisticRegression()
# fit the model
model.fit(X_important_train, y_train)
# get importance
importance = model.coef_[0]
list_features = []
# summarize feature importance
for i,v in enumerate(importance):
  if v != 0:
    list_features.append(i)
  print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

print("Linear Regression")
from sklearn.linear_model import LinearRegression
model = LinearRegression()
# fit the model
model.fit(X_important_train, y_train)
# get importance
importance = model.coef_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

print("DTC Regression")
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
# fit the model
model.fit(X_important_train, y_train)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

print("DTC Classifier")
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
# fit the model
model.fit(X_important_train, y_train)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

print("DTC RFRegressor")
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
# fit the model
model.fit(X_important_train, y_train)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()


print("DTC RFClassifier")
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
# fit the model
model.fit(X_important_train, y_train)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

print("DTC XGBRegressor")
from xgboost import XGBRegressor
model = XGBRegressor()
# fit the model
model.fit(X_important_train, y_train)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

print("DTC XGBClassifier")
from xgboost import XGBClassifier
model = XGBClassifier()
# fit the model
model.fit(X_important_train, y_train)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()


from sklearn.neighbors import KNeighborsRegressor
from sklearn.inspection import permutation_importance
model = KNeighborsRegressor()
# fit the model
model.fit(X_important_train, y_train)
# perform permutation importance
results = permutation_importance(model, X_important_train, y_train, scoring='neg_mean_squared_error')
# get importance
importance = results.importances_mean
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()


from sklearn.neighbors import KNeighborsClassifier
from sklearn.inspection import permutation_importance
model = KNeighborsClassifier()
# fit the model
model.fit(X_important_train, y_train)
# perform permutation importance
results = permutation_importance(model, X_important_train, y_train, scoring='accuracy')
# get importance
importance = results.importances_mean
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()



#-----------------------------------------------------------------------------

# print(list_features)
# selected_labels = [x for i,x in enumerate(feat_labels) if i in list_features]
# print(selected_labels)

# from sklearn import preprocessing
# le = preprocessing.LabelEncoder()

# newX_train = train[selected_labels]
# print(newX_train.head())
# y_train = train['label'].values

# newX_test = test[selected_labels]
# y_test = test['label'].values

# newX_train = newX_train.apply(le.fit_transform)
# y_train = le.fit_transform(y_train)

# newX_test = newX_test.apply(le.fit_transform)
# y_test = le.fit_transform(y_test)

# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# newX_important_train = scaler.fit_transform(newX_train)
# newX_important_test = scaler.fit_transform(newX_test)

# from sklearn.neural_network import MLPClassifier
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.svm import SVC
# from sklearn.gaussian_process import GaussianProcessClassifier
# from sklearn.gaussian_process.kernels import RBF
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
# from sklearn.naive_bayes import GaussianNB
# from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
# import datetime

# #training process
# dcs = DecisionTreeClassifier(max_depth=5)
# print("training DTC : ")
# now = datetime.datetime.now()
# print (now.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
# dcs.fit(newX_important_train,y_train)
# now = datetime.datetime.now()
# print (now.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
# print("___________________________")

# mlp = MLPClassifier(hidden_layer_sizes=(1, ))
# print("training MLP : ")
# now = datetime.datetime.now()
# print (now.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
# mlp.fit(newX_important_train,y_train)
# now = datetime.datetime.now()
# print (now.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
# print("___________________________")


# #prediction process
# from sklearn.metrics import classification_report
# from sklearn import metrics

# y_preddcs = dcs.predict(newX_important_test)
# y_predmlp = mlp.predict(newX_important_test)

# print("DTC Results : ")
# print(classification_report(y_test, y_preddcs))
# print("Accuracy:",metrics.accuracy_score(y_test, y_preddcs))

# print("___________________________")

# print("MLP Results : ")
# print(classification_report(y_test, y_predmlp))
# print("Accuracy:",metrics.accuracy_score(y_test, y_predmlp))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['datapath_id', 'version', 'header_length', 'tos', 'total_length', 'flags', 'offset', 'ttl', 'proto', 'csum', 'src_ip', 'dst_ip', 'src_port', 'dst_port', 'port_no', 'rx_bytes_ave', 'rx_error_ave', 'rx_dropped_ave', 'tx_bytes_ave', 'tx_error_ave', 'tx_dropped_ave', 'label']
# 160006
# 39994
# Logistic Regression
# Feature: 0, Score: 0.00000
# Feature: 1, Score: 0.00000
# Feature: 2, Score: 0.00000
# Feature: 3, Score: 0.00000
# Feature: 4, Score: -1.61720
# Feature: 5, Score: 6.76580
# Feature: 6, Score: 0.00000
# Feature: 7, Score: 0.00000
# Feature: 8, Score: 0.00000
# Feature: 9, Score: -0.00195
# Feature: 10, Score: -1.85064
# Feature: 11, Score: 0.00000
# Feature: 12, Score: -0.26961
# Feature: 13, Score: 0.00000
# Feature: 14, Score: -0.08737
# Feature: 15, Score: 3.04460
# Feature: 16, Score: 0.00000
# Feature: 17, Score: 0.00000
# Feature: 18, Score: 0.08789
# Feature: 19, Score: 0.00000
# Feature: 20, Score: 0.00000
# Linear Regression
# Feature: 0, Score: 0.00000
# Feature: 1, Score: 0.00000
# Feature: 2, Score: -0.00000
# Feature: 3, Score: 0.00000
# Feature: 4, Score: -0.00000
# Feature: 5, Score: 0.50000
# Feature: 6, Score: 0.00000
# Feature: 7, Score: 0.00000
# Feature: 8, Score: 0.00000
# Feature: 9, Score: -0.00000
# Feature: 10, Score: -0.00000
# Feature: 11, Score: -0.00000
# Feature: 12, Score: 0.00000
# Feature: 13, Score: 0.00000
# Feature: 14, Score: 0.00000
# Feature: 15, Score: 0.00000
# Feature: 16, Score: 0.00000
# Feature: 17, Score: 0.00000
# Feature: 18, Score: 0.00000
# Feature: 19, Score: 0.00000
# Feature: 20, Score: 0.00000
# DTC Regression
# Feature: 0, Score: 0.00000
# Feature: 1, Score: 0.00000
# Feature: 2, Score: 0.00000
# Feature: 3, Score: 0.00000
# Feature: 4, Score: 0.00000
# Feature: 5, Score: 0.00000
# Feature: 6, Score: 0.00000
# Feature: 7, Score: 0.00000
# Feature: 8, Score: 0.00000
# Feature: 9, Score: 0.00000
# Feature: 10, Score: 1.00000
# Feature: 11, Score: 0.00000
# Feature: 12, Score: 0.00000
# Feature: 13, Score: 0.00000
# Feature: 14, Score: 0.00000
# Feature: 15, Score: 0.00000
# Feature: 16, Score: 0.00000
# Feature: 17, Score: 0.00000
# Feature: 18, Score: 0.00000
# Feature: 19, Score: 0.00000
# Feature: 20, Score: 0.00000
# DTC Classifier
# Feature: 0, Score: 0.00000
# Feature: 1, Score: 0.00000
# Feature: 2, Score: 0.00000
# Feature: 3, Score: 0.00000
